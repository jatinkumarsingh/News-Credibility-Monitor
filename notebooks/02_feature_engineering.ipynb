# %%
# Importing Modules
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aryankinha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Loading Dataset
data=pd.read_csv("../data/interim/merged.csv")
data.head()
# Out:
#                                                title  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1  Trump drops Steve Bannon from National Securit...
# 2  Puerto Rico expects U.S. to lift Jones Act shi...
# 3   OOPS: Trump Just Accidentally Confirmed He Le...
# 4  Donald Trump heads for Scotland to reopen a go...
#
#                                                 text       subject  \
# 0  21st Century Wire says Ben Stein, reputable pr...       US_News
# 1  WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 2  (Reuters) - Puerto Rico Governor Ricardo Rosse...  politicsNews
# 3  On Monday, Donald Trump once again embarrassed...          News
# 4  GLASGOW, Scotland (Reuters) - Most U.S. presid...  politicsNews
#
#                   date  label  article_length
# 0    February 13, 2017      1             171
# 1       April 5, 2017       0             771
# 2  September 27, 2017       0             304
# 3         May 22, 2017      1             183
# 4       June 24, 2016       0             529

# %%
# Text Clearning
stop_words = set(stopwords.words("english"))

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)

data["clean_text"] = data["text"].apply(clean_text)

# %%
# Vectorizer the Text
vectorizer = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    stop_words="english"
)

X = vectorizer.fit_transform(data["clean_text"])

# %%
joblib.dump(vectorizer, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']

# %%
# Save Processed Data
data.to_csv("../data/processed/cleaned_data.csv", index=False)
